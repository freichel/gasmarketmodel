# %%
import pickle
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
t_gdf = pickle.load(open("/home/flo/code/freichel/gasmarketmodel/gasmarketmodel/data/temp/zoom.pkl", "rb"))

# %%
zoom_fig, zoom_ax = plt.subplots(figsize = (14, 12.0))

# %%
t_gdf.plot(ax = zoom_ax)
# Out:
# <AxesSubplot:>

# %%
pickle.dump(zoom_fig, open("/home/flo/code/freichel/gasmarketmodel/gasmarketmodel/data/temp/Deutschland.pkl", "wb"))

# %%
fig = pickle.load(open("/home/flo/code/freichel/gasmarketmodel/gasmarketmodel/data/temp/Deutschland.pkl", "rb"))
ax = fig.axes[0]
